# %%
import pandas as pd
import numpy as np
import seaborn as sns

#preprocessing libraries
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('clean_stroke_data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2     never smoked       1
# 3           smokes       1
# 4     never smoked       1

# %%
#label encoding categorical values
df['gender_map'] = df.gender.map({'Male':0, 'Female':1, 'Other':2})
df['evermarried_map'] = df.ever_married.map({'Yes':1, 'No':0})
df['worktype_map'] = df.work_type.map({'Private':0, 'Self-employed':1, 'Govt_job':2, 'children':3, 'Never_worked':4})
df['Residencetype_map'] = df.Residence_type.map({'Urban':0, 'Rural':1})
df['smokingstatus_map'] = df.smoking_status.map({'formerly smoked':0, 'never smoked':1, 'smokes':2, 'Unknown':3})

# %%
#gender_type = ('Male', 'Female', 'Other')
#ever_married_type = ('Yes', 'No')
#work_type = ('Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked')
#residence_type = ('Urban', 'Rural')
#smoking_status_type = ('formerly smoked', 'never smoked', 'smokes', 'Unknown')

#gender_df = pd.DataFrame(gender_type, columns=['gender_type'])
#dum_df = pd.get_dummies(gender_df, columns=['gender_type'], prefix=['Type_is'])

#ever_married_df = pd.DataFrame(ever_married_type, columns=['ever_married_type'])
#dum_df2 = pd.get_dummies(ever_married_df, columns=['ever_married_type'], prefix=['Type_is'])

#work_type_df = pd.DataFrame(work_type, columns=['work_type'])
#dum_df3 = pd.get_dummies(work_type_df, columns=['work_type'], prefix=['Type_is'])

#residence_type_df = pd.DataFrame(residence_type, columns=['residence_type'])
#dum_df4 = pd.get_dummies(residence_type_df, columns=['residence_type'], prefix=['Type_is'])

#smoking_status_type_df = pd.DataFrame(smoking_status_type, columns=['smoking_status_type'])
#dum_df5 = pd.get_dummies(smoking_status_type, columns=['smoking_status_type'], prefix=['Type_is'])
